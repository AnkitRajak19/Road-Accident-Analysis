# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Key Questions:-
#
# 1.What is The Cause of accidents?
#
# 2.Find Out The Number Of Accident By Country?
#
# 3.Find Out The Accident Distribution By Location?
#
# 4.How many Number of Injuries by Country?
#
# 5.Accident Distribution by Age Group.
#
# 6.Find Out The Accident Severity?
#
# 7.Find Out The Total Economic Loss by Country?

# %%
df = pd.read_csv('/content/drive/MyDrive/Data/road_accident_dataset 01.csv')

# %%
df
# Out:
#           Country  Year     Month Day of Week Time of Day Urban/Rural  \
# 0             USA  2002   October     Tuesday     Evening       Rural
# 1              UK  2014  December    Saturday     Evening       Urban
# 2             USA  2012      July      Sunday   Afternoon       Urban
# 3              UK  2017       May    Saturday     Evening       Urban
# 4          Canada  2002      July     Tuesday   Afternoon       Rural
# ...           ...   ...       ...         ...         ...         ...
# 131995    Germany  2023      June   Wednesday     Evening       Rural
# 131996     Brazil  2023   January     Tuesday     Morning       Rural
# 131997     Russia  2021     March   Wednesday   Afternoon       Urban
# 131998  Australia  2002       May     Tuesday     Morning       Urban
# 131999        USA  2022  November     Tuesday     Morning       Urban
#
#         Road Type Weather Conditions  Speed Limit Driver Age Group  ...  \
# ...

# %%
df.head()
# Out:
#   Country  Year     Month Day of Week Time of Day Urban/Rural  Road Type  \
# 0     USA  2002   October     Tuesday     Evening       Rural     Street
# 1      UK  2014  December    Saturday     Evening       Urban     Street
# 2     USA  2012      July      Sunday   Afternoon       Urban    Highway
# 3      UK  2017       May    Saturday     Evening       Urban  Main Road
# 4  Canada  2002      July     Tuesday   Afternoon       Rural    Highway
#
#   Weather Conditions  Speed Limit Driver Age Group  ... Driver Alcohol Level  \
# 0              Windy           37            18-25  ...             0.051921
# 1              Windy           96            18-25  ...             0.234893
# 2              Snowy           62            41-60  ...             0.142366
# 3              Clear           78            18-25  ...             0.120815
# 4              Rainy           98            41-60  ...             0.155842
#
#    Vehicle Condition Accident Severity Number of Injuries  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132000 entries, 0 to 131999
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Country                  132000 non-null  object
#  1   Year                     132000 non-null  int64
#  2   Month                    132000 non-null  object
#  3   Day of Week              132000 non-null  object
#  4   Time of Day              132000 non-null  object
#  5   Urban/Rural              132000 non-null  object
#  6   Road Type                132000 non-null  object
#  7   Weather Conditions       132000 non-null  object
#  8   Speed Limit              132000 non-null  int64
#  9   Driver Age Group         132000 non-null  object
#  10  Driver Gender            132000 non-null  object
#  11  Driver Alcohol Level     132000 non-null  float64
#  12  Vehicle Condition        132000 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Year    Speed Limit  Driver Alcohol Level  Number of Injuries  \
# count  132000.000000  132000.000000         132000.000000       132000.000000
# mean     2011.973348      74.544068              0.125232            9.508205
# std         7.198624      26.001448              0.072225            5.774366
# min      2000.000000      30.000000              0.000002            0.000000
# 25%      2006.000000      52.000000              0.062630            5.000000
# 50%      2012.000000      74.000000              0.125468            9.000000
# 75%      2018.000000      97.000000              0.187876           15.000000
# max      2024.000000     119.000000              0.249999           19.000000
#
#        Number of Fatalities  Emergency Response Time  Traffic Volume  \
# count         132000.000000            132000.000000   132000.000000
# mean               1.995439                32.491746     5041.929098
# ...

# %%
df.shape
# Out:
# (132000, 21)

# %%
df.isnull().sum()
# Out:
# Country                    0
# Year                       0
# Month                      0
# Day of Week                0
# Time of Day                0
# Urban/Rural                0
# Road Type                  0
# Weather Conditions         0
# Speed Limit                0
# Driver Age Group           0
# Driver Gender              0
# Driver Alcohol Level       0
# Vehicle Condition          0
# Accident Severity          0
# Number of Injuries         0
# Number of Fatalities       0
# Emergency Response Time    0
# Traffic Volume             0
# Accident Cause             0
# Economic Loss              0
# Region                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Month', 'Day of Week', 'Time of Day', 'Urban/Rural',
#        'Road Type', 'Weather Conditions', 'Speed Limit', 'Driver Age Group',
#        'Driver Gender', 'Driver Alcohol Level', 'Vehicle Condition',
#        'Accident Severity', 'Number of Injuries', 'Number of Fatalities',
#        'Emergency Response Time', 'Traffic Volume', 'Accident Cause',
#        'Economic Loss', 'Region'],
#       dtype='object')

# %%
df.head()
# Out:
#   Country  Year     Month Day of Week Time of Day Urban/Rural  Road Type  \
# 0     USA  2002   October     Tuesday     Evening       Rural     Street
# 1      UK  2014  December    Saturday     Evening       Urban     Street
# 2     USA  2012      July      Sunday   Afternoon       Urban    Highway
# 3      UK  2017       May    Saturday     Evening       Urban  Main Road
# 4  Canada  2002      July     Tuesday   Afternoon       Rural    Highway
#
#   Weather Conditions  Speed Limit Driver Age Group  ... Driver Alcohol Level  \
# 0              Windy           37            18-25  ...             0.051921
# 1              Windy           96            18-25  ...             0.234893
# 2              Snowy           62            41-60  ...             0.142366
# 3              Clear           78            18-25  ...             0.120815
# 4              Rainy           98            41-60  ...             0.155842
#
#    Vehicle Condition Accident Severity Number of Injuries  \
# ...

# %% [markdown]
# #1.What is The Cause of accidents?

# %%
accident_counts = df['Accident Cause'].value_counts()
print(accident_counts)
# Out:
# Accident Cause
# Drunk Driving         26506
# Distracted Driving    26460
# Speeding              26446
# Mechanical Failure    26343
# Weather               26245
# Name: count, dtype: int64

# %%
fig = px.pie(
    names=accident_counts.index,
    values=accident_counts.values,
    hole=0.5)

fig.update_traces(
    textinfo='percent+label',
    marker=dict(colors=px.colors.qualitative.Pastel))

fig.update_layout(title_text="Accident Causes")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #2.Find Out The Number Of Accident By Country?

# %%
country_accident_counts = df.groupby('Country')['Accident Cause'].count().reset_index()
country_accident_counts.rename(columns={'Accident Cause': 'Accident Count'}, inplace=True)
print(country_accident_counts)
# Out:
#      Country  Accident Count
# 0  Australia           13345
# 1     Brazil           13318
# 2     Canada           13349
# 3      China           13121
# 4    Germany           13293
# 5      India           13238
# 6      Japan           13049
# 7     Russia           12976
# 8         UK           13186
# 9        USA           13125

# %%
fig = px.bar(
    country_accident_counts,
    x='Country',
    y='Accident Count',
    title='Number of Accidents by Country'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #3.Find Out The Accident Distribution By Location?

# %%
urban_rural_counts = df['Urban/Rural'].value_counts()
print(urban_rural_counts)
# Out:
# Urban/Rural
# Rural    66502
# Urban    65498
# Name: count, dtype: int64

# %%
fig = px.pie(
    names=urban_rural_counts.index,
    values=urban_rural_counts.values,
    title='Accident Distribution by Location',
    hole=0.3)


fig.update_traces(
    textinfo='percent+label')



fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #4.How many Number of Injuries by Country?

# %%
country_injury_counts = df.groupby('Country')['Number of Injuries'].sum().reset_index()
print(country_injury_counts)
# Out:
#      Country  Number of Injuries
# 0  Australia              126912
# 1     Brazil              127753
# 2     Canada              126733
# 3      China              124277
# 4    Germany              126930
# 5      India              125739
# 6      Japan              124019
# 7     Russia              122796
# 8         UK              125508
# 9        USA              124416

# %%
fig = px.bar(
    country_injury_counts,
    x='Country',
    y='Number of Injuries',
    title='Number of Injuries by Country'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #5.Accident Distribution by Age Group.

# %%
age_group_accidents = df.groupby('Driver Age Group')['Accident Cause'].count().reset_index()
age_group_accidents.rename(columns={'Accident Cause': 'Accident Count'}, inplace=True)
print(age_group_accidents)
# Out:
#   Driver Age Group  Accident Count
# 0            18-25           26500
# 1            26-40           26492
# 2            41-60           26175
# 3              61+           26309
# 4              <18           26524

# %%
colors = ['#FFA07A', '#FA8072', '#E9967A', '#F08080', '#CD5C5C', '#DC143C']
fig = px.pie(
    age_group_accidents,
    values='Accident Count',
    names='Driver Age Group',
    hole=0.5,
    color_discrete_sequence=colors)

fig.update_traces(textinfo='percent+label')
fig.update_layout(title_text='Accident Distribution by Age Group')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#   Country  Year     Month Day of Week Time of Day Urban/Rural  Road Type  \
# 0     USA  2002   October     Tuesday     Evening       Rural     Street
# 1      UK  2014  December    Saturday     Evening       Urban     Street
# 2     USA  2012      July      Sunday   Afternoon       Urban    Highway
# 3      UK  2017       May    Saturday     Evening       Urban  Main Road
# 4  Canada  2002      July     Tuesday   Afternoon       Rural    Highway
#
#   Weather Conditions  Speed Limit Driver Age Group  ... Driver Alcohol Level  \
# 0              Windy           37            18-25  ...             0.051921
# 1              Windy           96            18-25  ...             0.234893
# 2              Snowy           62            41-60  ...             0.142366
# 3              Clear           78            18-25  ...             0.120815
# 4              Rainy           98            41-60  ...             0.155842
#
#    Vehicle Condition Accident Severity Number of Injuries  \
# ...

# %% [markdown]
# #6.Find Out The Accident Severity?

# %%
accident_severity_counts = df['Accident Severity'].value_counts().reset_index()

accident_severity_counts.columns = ['Severity', 'Count']

print(accident_severity_counts)
# Out:
#    Severity  Count
# 0     Minor  44063
# 1  Moderate  44002
# 2    Severe  43935

# %%
fig = px.bar(
    accident_severity_counts,
    x='Severity',
    y='Count',
    title='Accident Severity Distribution')

fig.update_layout(
    xaxis_title='Accident Severity',
    yaxis_title='Number of Accidents')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #7.Find Out The Total Economic Loss by Country?

# %%
country_economic_loss = df.groupby('Country')['Economic Loss'].sum().reset_index()
print(country_economic_loss)
# Out:
#      Country  Economic Loss
# 0  Australia   6.667312e+08
# 1     Brazil   6.756055e+08
# 2     Canada   6.782144e+08
# 3      China   6.655719e+08
# 4    Germany   6.702259e+08
# 5      India   6.669203e+08
# 6      Japan   6.541207e+08
# 7     Russia   6.524048e+08
# 8         UK   6.691604e+08
# 9        USA   6.587956e+08

# %%
fig = px.bar(
        country_economic_loss,
        x='Country',
        y='Economic Loss',
        title='Total Economic Loss by Country')


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Conclusion:-
#
# In conclusion, road accident analysis is crucial for understanding the multifaceted causes and consequences of traffic collisions. By examining factors such as human behavior, vehicle conditions, environmental influences, and accident distribution by location, age group, and severity, we can identify key areas where improvements are necessary. Human errors like distracted driving, speeding, and impaired judgment remain the leading causes, while vehicle malfunctions and poor road infrastructure also contribute significantly.
#
# Analyzing accident patterns by location reveals that urban areas tend to have more frequent accidents due to congestion, while rural areas experience fewer but often more severe incidents. Young drivers, especially those between 18-25 years old, are more prone to accidents due to inexperience, while older drivers face risks due to slower reflexes.
#
# The economic impact of road accidents is staggering, with billions of dollars lost annually in countries with high accident rates. These losses stem from medical expenses, lost productivity, and property damage. Through improved traffic laws, better road infrastructure, public awareness campaigns, and technological advancements in vehicle safety, road accidents can be reduced, saving lives and minimizing economic damage. Comprehensive road accident analysis provides valuable insights for policymakers, urban planners, and the public, fostering safer roads for all.
